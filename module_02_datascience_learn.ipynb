# %% [markdown]
# ## Модуль 2
# ### Блок 2

# %%
with open('module_02_user_ids.txt', 'r') as user_ids:
    for line in user_ids:
        print (line)
# Out:
# 1010
#
# 1036
#
# 1041
#
# 1041
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1042
#
# 1047
#
# 1047
#
# 1052
#
# 1052
#
# 1057
#
# 1057
#
# 1062
#
# 1067
#
# 1078
#
# 1085
#
# 1096
#
# 1098
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1100
#
# 1105
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1108
#
# 1111
#
# 1112
#
# 1112
#
# 1113
#
# 1113
#
# 1114
#
# 1114
#
# 1116
#
# 1118
#
# 1118
#
# 1123
#
# 1123
#
# 1128
#
# 1134
#
# 1134
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1135
#
# 1136
#
# 1136
#
# 1140
#
# 1140
#
# 1141
#
# 1145
#
# 1145
#
# 1149
#
# 1149
#
# 1149
#
# 1149
#
# 1149
#
# 1149
#
# 1149
#
# 1150
#
# 1154
#
# 1154
#
# 1159
#
# 1159
#
# 1164
#
# 1167
#
# 1175
#
# 1181
#
# 1182
#
# 1182
#
# 1193
#
# 1193
#
# 1198
#
# 1198
#
# 1201
#
# 1203
#
# 1203
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1207
#
# 1208
#
# 1208
#
# 1209
#
# 1213
#
# 1213
#
# 1218
#
# 1218
#
# 1219
#
# 1223
#
# 1223
#
# 1224
#
# 1226
#
# 1226
#
# 1228
#
# 1228
#
# 1230
#
# 1233
#
# 1233
#
# 1236
#
# 1238
#
# 1238
#
# 1242
#
# 1243
#
# 1243
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1246
#
# 1248
#
# 1248
#
# 1252
#
# 1252
#
# 1253
#
# 1253
#
# 1258
#
# 1258
#
# 1263
#
# 1263
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1267
#
# 1268
#
# 1268
#
# 1269
#
# 1270
#
# 1273
#
# 1273
#
# 1274
#
# 1278
#
# 1278
#
# 1279
#
# 1281
#
# 1283
#
# 1283
#
# 1288
#
# 1288
#
# 1291
#
# 1293
#
# 1293
#
# 1294
#
# 1296
#
# 1298
#
# 1298
#
# 1298
#
# 1300
#
# 1300
#
# 1302
#
# 1303
#
# 1303
#
# 1308
#
# 1308
#
# 1313
#
# 1313
#
# 1315
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1318
#
# 1320
#
# 1323
#
# 1323
#
# 1328
#
# 1328
#
# 1330
#
# 1331
#
# 1332
#
# 1333
#
# 1334
#
# 1343
#
# 1350
#
# 1351
#
# 1353
#
# 1354
#
# 1355
#
# 1359
#
# 1362
#
# 1363
#
# 1364
#
# 1366
#
# 1367
#
# 1371
#
# 1372
#
# 1374
#
# 1377
#
# 1380
#
# 1382
#
# 1383
#
# 1386
#
# 1387
#
# 1388
#
# 1392
#
# 1393
#
# 1394
#
# 1397
#
# 1398
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424
#
# 1424

# %%
with open('module_02_user_ids.txt', 'r') as user_ids:
    for line in user_ids:
        print (line.strip())
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
user_ids = []

with open('module_02_user_ids.txt', 'r') as file:
    for line in file:
        user_ids.append(line.strip())
for x in range(0,5) :
    print (user_ids[x])
print('-')
print('Всего ID в файле {}'.format (len(user_ids)))
print('-')
unique_ids = set(user_ids)
print('Уникальных ID в файле {}'.format (len(unique_ids)))
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# -
# Всего ID в файле 294
# -
# Уникальных ID в файле 124

# %% [markdown]
# ### Блок 3

# %%
with open('module_02_user_ids_headers.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# user_id
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
Started = True

with open('module_02_user_ids_headers.txt', 'r') as file:
    for line in file:
        if Started:
            Started = False
        else:
            print(line.strip())
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# seo	google	20,20
# sem	yandex	15,60
# email	promo	13,20
# sem	yandex	9,80
# sem	google	14,80
# sem	google	14,40
# sem	google	14,00
# brand	yandex	20,00
# sem	yandex	16,20
# email	promo	11,00
# cpa-partners	burgerclub	10,80
# seo	google	22,60
# seo	google	22,40
# sem	yandex	24,40
# seo	google	16,60
# sem	yandex	8,60
# seo	yandex	12,40
# cpa-partners	food-delivery	16,20
# email	promo	24,00
# sem	yandex	18,80
# email	promo	11,80
# sem	google	9,40
# sem	google	11,20
# email	promo	19,00
# sem	google	23,40
# cpc-partners	city-magazine	17,00
# seo	google	20,80
# email	promo	15,60
# cpc-partners	foody	22,40
# seo	yandex	15,60
# cpa-partners	food-delivery	21,00
# seo	google	22,40
# sem	google	20,40
# email	promo	26,00
# seo	yandex	18,40
# email	promo	14,60
# seo	yandex	29,80
# email	promo	20,00
# sem	google	19,00
# brand	google	16,40
# sem	yandex	16,20
# sem	yandex	17,80
# email	promo	18,80
# cpa-partners	burgerclub	20,00
# seo	google	21,00
# seo	yandex	16,60
# email	promo	20,00
# sem	yandex	19,80
# email	promo	16,80
# cpa-partners	food-delivery	24,00
# sem	yandex	12,00
# sem	yandex	10,20
# email	promo	24,00
# sem	yandex	15,80
# sem	yandex	22,00
# sem	google	17,40
# sem	yandex	14,80
# email	promo	20,00
# brand	yandex	11,60
# seo	yandex	20,00
# sem	yandex	16,00
# seo	yandex	11,20
# seo	google	12,20
# sem	yandex	19,20
# sem	google	17,80
# sem	google	19,80
# email	promo	8,60
# email	promo	28,60
# email	newsletter	18,80
# sem	google	17,60
# email	promo	16,00
# cpa-partners	food-delivery	15,40
# sem	yandex	21,60
# email	promo	7,60
# brand	yandex	21,60
# smm	facebook	17,40
# sem	google	22,00
# email	promo	22,00
# email	promo	16,00
# seo	yandex	16,00
# sem	yandex	20,00
# email	promo	10,00
# sem	yandex	21,20
# seo	yandex	30,40
# cpa-partners	burgerclub	18,80
# sem	yandex	14,00
# email	promo	22,00
# sem	google	16,00
# sem	yandex	12,60
# sem	google	13,40
# seo	yandex	13,60
# sem	yandex	10,20
# brand	yandex	17,40
# sem	google	22,40
# sem	yandex	11,40
# sem	google	14,00
# seo	yandex	22,40
# sem	yandex	18,00
# brand	direct	17,00
# cpa-partners	food-delivery	24,80
# brand	google	16,60
# sem	google	17,80
# sem	google	9,00
# email	promo	10,60
# brand	google	23,40
# cpa-partners	burgerclub	21,00
# email	promo	16,60
# cpc-partners	foody	24,20
# seo	google	20,40
# seo	yandex	25,60
# brand	yandex	19,80
# smm	facebook	16,40
# email	promo	16,20
# seo	yandex	17,00
# email	promo	16,80
# sem	yandex	19,80
# seo	yandex	15,60
# email	newsletter	19,20
# sem	google	23,20
# sem	yandex	10,80
# sem	google	24,40
# sem	yandex	13,40
# seo	yandex	12,00
# smm	facebook	18,60
# sem	google	16,60
# cpa-partners	burgerclub	12,20
# cpa-partners	burgerclub	22,40
# seo	google	15,40
# cpc-partners	city-magazine	17,20
# cpa-partners	burgerclub	17,60
# email	promo	16,40
# email	promo	18,60
# email	promo	19,80
# brand	google	18,80
# seo	google	17,60
# email	promo	20,60
# cpa-partners	food-delivery	15,00
# sem	yandex	22,00
# email	promo	17,40
# seo	yandex	13,60
# seo	yandex	17,60
# email	promo	18,40
# email	promo	20,40
# sem	yandex	20,00
# brand	yandex	17,80
# seo	google	16,00
# email	promo	14,60
# email	promo	17,20
# sem	yandex	13,60
# email	promo	23,60
# sem	google	15,60
# sem	yandex	21,40
# sem	google	13,00
# seo	yandex	18,60
# cpa-partners	burgerclub	20,60
# seo	yandex	11,40
# email	promo	18,00
# smm	vk	12,00
# sem	yandex	16,00
# sem	google	12,20
# brand	direct	23,00
# sem	yandex	24,00
# email	promo	11,80
# email	newsletter	17,20
# email	newsletter	24,60
# sem	yandex	30,40
# sem	yandex	18,00
# email	promo	15,00
# sem	google	13,20
# seo	yandex	28,80
# sem	yandex	22,00
# email	promo	15,60
# sem	yandex	13,60
# sem	google	8,60
# sem	google	22,00
# email	promo	20,00
# sem	yandex	12,60
# sem	google	18,00
# brand	direct	11,00
# email	promo	12,20
# sem	yandex	18,00
# email	promo	12,40
# seo	google	13,00
# brand	direct	21,40
# sem	yandex	13,60
# cpa-partners	food-delivery	17,40
# sem	google	15,00
# seo	yandex	14,40
# brand	direct	16,00
# seo	yandex	12,00
# sem	yandex	12,80
# email	promo	21,40
# sem	yandex	17,40
# sem	yandex	21,60
# email	promo	16,00
# sem	google	16,40
# sem	yandex	16,00
# email	promo	22,00
# brand	yandex	21,80
# email	promo	14,60
# seo	yandex	22,00
# email	promo	25,00
# sem	google	15,60
# email	promo	17,80
# sem	yandex	14,80
# sem	yandex	18,20
# sem	google	12,60
# email	promo	11,80
# sem	yandex	16,00
# seo	yandex	30,40
# seo	google	13,40
# email	newsletter	18,40
# email	promo	20,00
# smm	vk	17,00
# sem	google	26,00
# sem	google	21,00
# cpc-partners	foody	19,40
# sem	yandex	16,00
# sem	yandex	12,80
# sem	google	14,00
# cpa-partners	burgerclub	21,80
# cpc-partners	city-magazine	11,80
# sem	google	25,80
# sem	google	18,00
# sem	google	10,20
# email	promo	12,00
# sem	google	13,80
# sem	google	16,60
# sem	google	11,40
# brand	google	13,40
# sem	yandex	14,00
# sem	google	16,60
# email	promo	24,00
# email	promo	10,20
# email	promo	18,60
# sem	yandex	21,60
# cpa-partners	burgerclub	20,20
# sem	yandex	18,00
# email	promo	17,40
# email	promo	22,00
# sem	yandex	17,40
# sem	yandex	19,00
# smm	facebook	18,00
# brand	google	16,00
# email	promo	28,60
# sem	yandex	18,40
# email	promo	18,80
# seo	yandex	17,80
# sem	yandex	16,80
# sem	yandex	19,40
# sem	google	20,00
# sem	yandex	16,00
# sem	google	22,00
# cpa-partners	food-delivery	12,80
# email	promo	20,00
# sem	yandex	17,40
# email	promo	15,60
# sem	google	22,00
# sem	google	14,40
# sem	google	12,20
# seo	yandex	12,20
# email	promo	20,00
# cpa-partners	food-delivery	13,00
# sem	yandex	22,40
# sem	yandex	13,60
# sem	google	30,40
# sem	yandex	12,40
# sem	yandex	16,00
# seo	yandex	30,40
# cpc-partners	city-magazine	23,20
# sem	google	20,00
# email	promo	12,60
# sem	google	14,60
# cpc-partners	city-magazine	11,80
# smm	facebook	20,20
# sem	google	10,00
# email	promo	12,80
# sem	yandex	20,60
# seo	yandex	18,00
# cpa-partners	food-delivery	13,80
# seo	yandex	12,80
# sem	yandex	17,20
# sem	google	16,00
# email	promo	14,20
# sem	yandex	19,60
# seo	google	22,40
# email	promo	14,80
# sem	google	13,00
# sem	google	13,60
# email	promo	12,60
# seo	yandex	19,20
# email	promo	20,20
# sem	google	16,00
# sem	yandex	11,60

# %%
with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        print(line.strip().split('\t'))
# Out:
# ['seo', 'google', '20,20']
# ['sem', 'yandex', '15,60']
# ['email', 'promo', '13,20']
# ['sem', 'yandex', '9,80']
# ['sem', 'google', '14,80']
# ['sem', 'google', '14,40']
# ['sem', 'google', '14,00']
# ['brand', 'yandex', '20,00']
# ['sem', 'yandex', '16,20']
# ['email', 'promo', '11,00']
# ['cpa-partners', 'burgerclub', '10,80']
# ['seo', 'google', '22,60']
# ['seo', 'google', '22,40']
# ['sem', 'yandex', '24,40']
# ['seo', 'google', '16,60']
# ['sem', 'yandex', '8,60']
# ['seo', 'yandex', '12,40']
# ['cpa-partners', 'food-delivery', '16,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '18,80']
# ['email', 'promo', '11,80']
# ['sem', 'google', '9,40']
# ['sem', 'google', '11,20']
# ['email', 'promo', '19,00']
# ['sem', 'google', '23,40']
# ['cpc-partners', 'city-magazine', '17,00']
# ['seo', 'google', '20,80']
# ['email', 'promo', '15,60']
# ['cpc-partners', 'foody', '22,40']
# ['seo', 'yandex', '15,60']
# ['cpa-partners', 'food-delivery', '21,00']
# ['seo', 'google', '22,40']
# ['sem', 'google', '20,40']
# ['email', 'promo', '26,00']
# ['seo', 'yandex', '18,40']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '29,80']
# ['email', 'promo', '20,00']
# ['sem', 'google', '19,00']
# ['brand', 'google', '16,40']
# ['sem', 'yandex', '16,20']
# ['sem', 'yandex', '17,80']
# ['email', 'promo', '18,80']
# ['cpa-partners', 'burgerclub', '20,00']
# ['seo', 'google', '21,00']
# ['seo', 'yandex', '16,60']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '19,80']
# ['email', 'promo', '16,80']
# ['cpa-partners', 'food-delivery', '24,00']
# ['sem', 'yandex', '12,00']
# ['sem', 'yandex', '10,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '15,80']
# ['sem', 'yandex', '22,00']
# ['sem', 'google', '17,40']
# ['sem', 'yandex', '14,80']
# ['email', 'promo', '20,00']
# ['brand', 'yandex', '11,60']
# ['seo', 'yandex', '20,00']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '11,20']
# ['seo', 'google', '12,20']
# ['sem', 'yandex', '19,20']
# ['sem', 'google', '17,80']
# ['sem', 'google', '19,80']
# ['email', 'promo', '8,60']
# ['email', 'promo', '28,60']
# ['email', 'newsletter', '18,80']
# ['sem', 'google', '17,60']
# ['email', 'promo', '16,00']
# ['cpa-partners', 'food-delivery', '15,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '7,60']
# ['brand', 'yandex', '21,60']
# ['smm', 'facebook', '17,40']
# ['sem', 'google', '22,00']
# ['email', 'promo', '22,00']
# ['email', 'promo', '16,00']
# ['seo', 'yandex', '16,00']
# ['sem', 'yandex', '20,00']
# ['email', 'promo', '10,00']
# ['sem', 'yandex', '21,20']
# ['seo', 'yandex', '30,40']
# ['cpa-partners', 'burgerclub', '18,80']
# ['sem', 'yandex', '14,00']
# ['email', 'promo', '22,00']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '13,40']
# ['seo', 'yandex', '13,60']
# ['sem', 'yandex', '10,20']
# ['brand', 'yandex', '17,40']
# ['sem', 'google', '22,40']
# ['sem', 'yandex', '11,40']
# ['sem', 'google', '14,00']
# ['seo', 'yandex', '22,40']
# ['sem', 'yandex', '18,00']
# ['brand', 'direct', '17,00']
# ['cpa-partners', 'food-delivery', '24,80']
# ['brand', 'google', '16,60']
# ['sem', 'google', '17,80']
# ['sem', 'google', '9,00']
# ['email', 'promo', '10,60']
# ['brand', 'google', '23,40']
# ['cpa-partners', 'burgerclub', '21,00']
# ['email', 'promo', '16,60']
# ['cpc-partners', 'foody', '24,20']
# ['seo', 'google', '20,40']
# ['seo', 'yandex', '25,60']
# ['brand', 'yandex', '19,80']
# ['smm', 'facebook', '16,40']
# ['email', 'promo', '16,20']
# ['seo', 'yandex', '17,00']
# ['email', 'promo', '16,80']
# ['sem', 'yandex', '19,80']
# ['seo', 'yandex', '15,60']
# ['email', 'newsletter', '19,20']
# ['sem', 'google', '23,20']
# ['sem', 'yandex', '10,80']
# ['sem', 'google', '24,40']
# ['sem', 'yandex', '13,40']
# ['seo', 'yandex', '12,00']
# ['smm', 'facebook', '18,60']
# ['sem', 'google', '16,60']
# ['cpa-partners', 'burgerclub', '12,20']
# ['cpa-partners', 'burgerclub', '22,40']
# ['seo', 'google', '15,40']
# ['cpc-partners', 'city-magazine', '17,20']
# ['cpa-partners', 'burgerclub', '17,60']
# ['email', 'promo', '16,40']
# ['email', 'promo', '18,60']
# ['email', 'promo', '19,80']
# ['brand', 'google', '18,80']
# ['seo', 'google', '17,60']
# ['email', 'promo', '20,60']
# ['cpa-partners', 'food-delivery', '15,00']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '17,40']
# ['seo', 'yandex', '13,60']
# ['seo', 'yandex', '17,60']
# ['email', 'promo', '18,40']
# ['email', 'promo', '20,40']
# ['sem', 'yandex', '20,00']
# ['brand', 'yandex', '17,80']
# ['seo', 'google', '16,00']
# ['email', 'promo', '14,60']
# ['email', 'promo', '17,20']
# ['sem', 'yandex', '13,60']
# ['email', 'promo', '23,60']
# ['sem', 'google', '15,60']
# ['sem', 'yandex', '21,40']
# ['sem', 'google', '13,00']
# ['seo', 'yandex', '18,60']
# ['cpa-partners', 'burgerclub', '20,60']
# ['seo', 'yandex', '11,40']
# ['email', 'promo', '18,00']
# ['smm', 'vk', '12,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '12,20']
# ['brand', 'direct', '23,00']
# ['sem', 'yandex', '24,00']
# ['email', 'promo', '11,80']
# ['email', 'newsletter', '17,20']
# ['email', 'newsletter', '24,60']
# ['sem', 'yandex', '30,40']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '15,00']
# ['sem', 'google', '13,20']
# ['seo', 'yandex', '28,80']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '15,60']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '8,60']
# ['sem', 'google', '22,00']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '18,00']
# ['brand', 'direct', '11,00']
# ['email', 'promo', '12,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '12,40']
# ['seo', 'google', '13,00']
# ['brand', 'direct', '21,40']
# ['sem', 'yandex', '13,60']
# ['cpa-partners', 'food-delivery', '17,40']
# ['sem', 'google', '15,00']
# ['seo', 'yandex', '14,40']
# ['brand', 'direct', '16,00']
# ['seo', 'yandex', '12,00']
# ['sem', 'yandex', '12,80']
# ['email', 'promo', '21,40']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '16,00']
# ['sem', 'google', '16,40']
# ['sem', 'yandex', '16,00']
# ['email', 'promo', '22,00']
# ['brand', 'yandex', '21,80']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '22,00']
# ['email', 'promo', '25,00']
# ['sem', 'google', '15,60']
# ['email', 'promo', '17,80']
# ['sem', 'yandex', '14,80']
# ['sem', 'yandex', '18,20']
# ['sem', 'google', '12,60']
# ['email', 'promo', '11,80']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['seo', 'google', '13,40']
# ['email', 'newsletter', '18,40']
# ['email', 'promo', '20,00']
# ['smm', 'vk', '17,00']
# ['sem', 'google', '26,00']
# ['sem', 'google', '21,00']
# ['cpc-partners', 'foody', '19,40']
# ['sem', 'yandex', '16,00']
# ['sem', 'yandex', '12,80']
# ['sem', 'google', '14,00']
# ['cpa-partners', 'burgerclub', '21,80']
# ['cpc-partners', 'city-magazine', '11,80']
# ['sem', 'google', '25,80']
# ['sem', 'google', '18,00']
# ['sem', 'google', '10,20']
# ['email', 'promo', '12,00']
# ['sem', 'google', '13,80']
# ['sem', 'google', '16,60']
# ['sem', 'google', '11,40']
# ['brand', 'google', '13,40']
# ['sem', 'yandex', '14,00']
# ['sem', 'google', '16,60']
# ['email', 'promo', '24,00']
# ['email', 'promo', '10,20']
# ['email', 'promo', '18,60']
# ['sem', 'yandex', '21,60']
# ['cpa-partners', 'burgerclub', '20,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '17,40']
# ['email', 'promo', '22,00']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '19,00']
# ['smm', 'facebook', '18,00']
# ['brand', 'google', '16,00']
# ['email', 'promo', '28,60']
# ['sem', 'yandex', '18,40']
# ['email', 'promo', '18,80']
# ['seo', 'yandex', '17,80']
# ['sem', 'yandex', '16,80']
# ['sem', 'yandex', '19,40']
# ['sem', 'google', '20,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '22,00']
# ['cpa-partners', 'food-delivery', '12,80']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '17,40']
# ['email', 'promo', '15,60']
# ['sem', 'google', '22,00']
# ['sem', 'google', '14,40']
# ['sem', 'google', '12,20']
# ['seo', 'yandex', '12,20']
# ['email', 'promo', '20,00']
# ['cpa-partners', 'food-delivery', '13,00']
# ['sem', 'yandex', '22,40']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '30,40']
# ['sem', 'yandex', '12,40']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['cpc-partners', 'city-magazine', '23,20']
# ['sem', 'google', '20,00']
# ['email', 'promo', '12,60']
# ['sem', 'google', '14,60']
# ['cpc-partners', 'city-magazine', '11,80']
# ['smm', 'facebook', '20,20']
# ['sem', 'google', '10,00']
# ['email', 'promo', '12,80']
# ['sem', 'yandex', '20,60']
# ['seo', 'yandex', '18,00']
# ['cpa-partners', 'food-delivery', '13,80']
# ['seo', 'yandex', '12,80']
# ['sem', 'yandex', '17,20']
# ['sem', 'google', '16,00']
# ['email', 'promo', '14,20']
# ['sem', 'yandex', '19,60']
# ['seo', 'google', '22,40']
# ['email', 'promo', '14,80']
# ['sem', 'google', '13,00']
# ['sem', 'google', '13,60']
# ['email', 'promo', '12,60']
# ['seo', 'yandex', '19,20']
# ['email', 'promo', '20,20']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '11,60']

# %%
with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = line[2].replace(',','.')
        print (line)
        print (medium, source, amount_paid)
# Out:
# ['seo', 'google', '20,20']
# seo google 20.20
# ['sem', 'yandex', '15,60']
# sem yandex 15.60
# ['email', 'promo', '13,20']
# email promo 13.20
# ['sem', 'yandex', '9,80']
# sem yandex 9.80
# ['sem', 'google', '14,80']
# sem google 14.80
# ['sem', 'google', '14,40']
# sem google 14.40
# ['sem', 'google', '14,00']
# sem google 14.00
# ['brand', 'yandex', '20,00']
# brand yandex 20.00
# ['sem', 'yandex', '16,20']
# sem yandex 16.20
# ['email', 'promo', '11,00']
# email promo 11.00
# ['cpa-partners', 'burgerclub', '10,80']
# cpa-partners burgerclub 10.80
# ['seo', 'google', '22,60']
# seo google 22.60
# ['seo', 'google', '22,40']
# seo google 22.40
# ['sem', 'yandex', '24,40']
# sem yandex 24.40
# ['seo', 'google', '16,60']
# seo google 16.60
# ['sem', 'yandex', '8,60']
# sem yandex 8.60
# ['seo', 'yandex', '12,40']
# seo yandex 12.40
# ['cpa-partners', 'food-delivery', '16,20']
# cpa-partners food-delivery 16.20
# ['email', 'promo', '24,00']
# email promo 24.00
# ['sem', 'yandex', '18,80']
# sem yandex 18.80
# ['email', 'promo', '11,80']
# email promo 11.80
# ['sem', 'google', '9,40']
# sem google 9.40
# ['sem', 'google', '11,20']
# sem google 11.20
# ['email', 'promo', '19,00']
# email promo 19.00
# ['sem', 'google', '23,40']
# sem google 23.40
# ['cpc-partners', 'city-magazine', '17,00']
# cpc-partners city-magazine 17.00
# ['seo', 'google', '20,80']
# seo google 20.80
# ['email', 'promo', '15,60']
# email promo 15.60
# ['cpc-partners', 'foody', '22,40']
# cpc-partners foody 22.40
# ['seo', 'yandex', '15,60']
# seo yandex 15.60
# ['cpa-partners', 'food-delivery', '21,00']
# cpa-partners food-delivery 21.00
# ['seo', 'google', '22,40']
# seo google 22.40
# ['sem', 'google', '20,40']
# sem google 20.40
# ['email', 'promo', '26,00']
# email promo 26.00
# ['seo', 'yandex', '18,40']
# seo yandex 18.40
# ['email', 'promo', '14,60']
# email promo 14.60
# ['seo', 'yandex', '29,80']
# seo yandex 29.80
# ['email', 'promo', '20,00']
# email promo 20.00
# ['sem', 'google', '19,00']
# sem google 19.00
# ['brand', 'google', '16,40']
# brand google 16.40
# ['sem', 'yandex', '16,20']
# sem yandex 16.20
# ['sem', 'yandex', '17,80']
# sem yandex 17.80
# ['email', 'promo', '18,80']
# email promo 18.80
# ['cpa-partners', 'burgerclub', '20,00']
# cpa-partners burgerclub 20.00
# ['seo', 'google', '21,00']
# seo google 21.00
# ['seo', 'yandex', '16,60']
# seo yandex 16.60
# ['email', 'promo', '20,00']
# email promo 20.00
# ['sem', 'yandex', '19,80']
# sem yandex 19.80
# ['email', 'promo', '16,80']
# email promo 16.80
# ['cpa-partners', 'food-delivery', '24,00']
# cpa-partners food-delivery 24.00
# ['sem', 'yandex', '12,00']
# sem yandex 12.00
# ['sem', 'yandex', '10,20']
# sem yandex 10.20
# ['email', 'promo', '24,00']
# email promo 24.00
# ['sem', 'yandex', '15,80']
# sem yandex 15.80
# ['sem', 'yandex', '22,00']
# sem yandex 22.00
# ['sem', 'google', '17,40']
# sem google 17.40
# ['sem', 'yandex', '14,80']
# sem yandex 14.80
# ['email', 'promo', '20,00']
# email promo 20.00
# ['brand', 'yandex', '11,60']
# brand yandex 11.60
# ['seo', 'yandex', '20,00']
# seo yandex 20.00
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['seo', 'yandex', '11,20']
# seo yandex 11.20
# ['seo', 'google', '12,20']
# seo google 12.20
# ['sem', 'yandex', '19,20']
# sem yandex 19.20
# ['sem', 'google', '17,80']
# sem google 17.80
# ['sem', 'google', '19,80']
# sem google 19.80
# ['email', 'promo', '8,60']
# email promo 8.60
# ['email', 'promo', '28,60']
# email promo 28.60
# ['email', 'newsletter', '18,80']
# email newsletter 18.80
# ['sem', 'google', '17,60']
# sem google 17.60
# ['email', 'promo', '16,00']
# email promo 16.00
# ['cpa-partners', 'food-delivery', '15,40']
# cpa-partners food-delivery 15.40
# ['sem', 'yandex', '21,60']
# sem yandex 21.60
# ['email', 'promo', '7,60']
# email promo 7.60
# ['brand', 'yandex', '21,60']
# brand yandex 21.60
# ['smm', 'facebook', '17,40']
# smm facebook 17.40
# ['sem', 'google', '22,00']
# sem google 22.00
# ['email', 'promo', '22,00']
# email promo 22.00
# ['email', 'promo', '16,00']
# email promo 16.00
# ['seo', 'yandex', '16,00']
# seo yandex 16.00
# ['sem', 'yandex', '20,00']
# sem yandex 20.00
# ['email', 'promo', '10,00']
# email promo 10.00
# ['sem', 'yandex', '21,20']
# sem yandex 21.20
# ['seo', 'yandex', '30,40']
# seo yandex 30.40
# ['cpa-partners', 'burgerclub', '18,80']
# cpa-partners burgerclub 18.80
# ['sem', 'yandex', '14,00']
# sem yandex 14.00
# ['email', 'promo', '22,00']
# email promo 22.00
# ['sem', 'google', '16,00']
# sem google 16.00
# ['sem', 'yandex', '12,60']
# sem yandex 12.60
# ['sem', 'google', '13,40']
# sem google 13.40
# ['seo', 'yandex', '13,60']
# seo yandex 13.60
# ['sem', 'yandex', '10,20']
# sem yandex 10.20
# ['brand', 'yandex', '17,40']
# brand yandex 17.40
# ['sem', 'google', '22,40']
# sem google 22.40
# ['sem', 'yandex', '11,40']
# sem yandex 11.40
# ['sem', 'google', '14,00']
# sem google 14.00
# ['seo', 'yandex', '22,40']
# seo yandex 22.40
# ['sem', 'yandex', '18,00']
# sem yandex 18.00
# ['brand', 'direct', '17,00']
# brand direct 17.00
# ['cpa-partners', 'food-delivery', '24,80']
# cpa-partners food-delivery 24.80
# ['brand', 'google', '16,60']
# brand google 16.60
# ['sem', 'google', '17,80']
# sem google 17.80
# ['sem', 'google', '9,00']
# sem google 9.00
# ['email', 'promo', '10,60']
# email promo 10.60
# ['brand', 'google', '23,40']
# brand google 23.40
# ['cpa-partners', 'burgerclub', '21,00']
# cpa-partners burgerclub 21.00
# ['email', 'promo', '16,60']
# email promo 16.60
# ['cpc-partners', 'foody', '24,20']
# cpc-partners foody 24.20
# ['seo', 'google', '20,40']
# seo google 20.40
# ['seo', 'yandex', '25,60']
# seo yandex 25.60
# ['brand', 'yandex', '19,80']
# brand yandex 19.80
# ['smm', 'facebook', '16,40']
# smm facebook 16.40
# ['email', 'promo', '16,20']
# email promo 16.20
# ['seo', 'yandex', '17,00']
# seo yandex 17.00
# ['email', 'promo', '16,80']
# email promo 16.80
# ['sem', 'yandex', '19,80']
# sem yandex 19.80
# ['seo', 'yandex', '15,60']
# seo yandex 15.60
# ['email', 'newsletter', '19,20']
# email newsletter 19.20
# ['sem', 'google', '23,20']
# sem google 23.20
# ['sem', 'yandex', '10,80']
# sem yandex 10.80
# ['sem', 'google', '24,40']
# sem google 24.40
# ['sem', 'yandex', '13,40']
# sem yandex 13.40
# ['seo', 'yandex', '12,00']
# seo yandex 12.00
# ['smm', 'facebook', '18,60']
# smm facebook 18.60
# ['sem', 'google', '16,60']
# sem google 16.60
# ['cpa-partners', 'burgerclub', '12,20']
# cpa-partners burgerclub 12.20
# ['cpa-partners', 'burgerclub', '22,40']
# cpa-partners burgerclub 22.40
# ['seo', 'google', '15,40']
# seo google 15.40
# ['cpc-partners', 'city-magazine', '17,20']
# cpc-partners city-magazine 17.20
# ['cpa-partners', 'burgerclub', '17,60']
# cpa-partners burgerclub 17.60
# ['email', 'promo', '16,40']
# email promo 16.40
# ['email', 'promo', '18,60']
# email promo 18.60
# ['email', 'promo', '19,80']
# email promo 19.80
# ['brand', 'google', '18,80']
# brand google 18.80
# ['seo', 'google', '17,60']
# seo google 17.60
# ['email', 'promo', '20,60']
# email promo 20.60
# ['cpa-partners', 'food-delivery', '15,00']
# cpa-partners food-delivery 15.00
# ['sem', 'yandex', '22,00']
# sem yandex 22.00
# ['email', 'promo', '17,40']
# email promo 17.40
# ['seo', 'yandex', '13,60']
# seo yandex 13.60
# ['seo', 'yandex', '17,60']
# seo yandex 17.60
# ['email', 'promo', '18,40']
# email promo 18.40
# ['email', 'promo', '20,40']
# email promo 20.40
# ['sem', 'yandex', '20,00']
# sem yandex 20.00
# ['brand', 'yandex', '17,80']
# brand yandex 17.80
# ['seo', 'google', '16,00']
# seo google 16.00
# ['email', 'promo', '14,60']
# email promo 14.60
# ['email', 'promo', '17,20']
# email promo 17.20
# ['sem', 'yandex', '13,60']
# sem yandex 13.60
# ['email', 'promo', '23,60']
# email promo 23.60
# ['sem', 'google', '15,60']
# sem google 15.60
# ['sem', 'yandex', '21,40']
# sem yandex 21.40
# ['sem', 'google', '13,00']
# sem google 13.00
# ['seo', 'yandex', '18,60']
# seo yandex 18.60
# ['cpa-partners', 'burgerclub', '20,60']
# cpa-partners burgerclub 20.60
# ['seo', 'yandex', '11,40']
# seo yandex 11.40
# ['email', 'promo', '18,00']
# email promo 18.00
# ['smm', 'vk', '12,00']
# smm vk 12.00
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['sem', 'google', '12,20']
# sem google 12.20
# ['brand', 'direct', '23,00']
# brand direct 23.00
# ['sem', 'yandex', '24,00']
# sem yandex 24.00
# ['email', 'promo', '11,80']
# email promo 11.80
# ['email', 'newsletter', '17,20']
# email newsletter 17.20
# ['email', 'newsletter', '24,60']
# email newsletter 24.60
# ['sem', 'yandex', '30,40']
# sem yandex 30.40
# ['sem', 'yandex', '18,00']
# sem yandex 18.00
# ['email', 'promo', '15,00']
# email promo 15.00
# ['sem', 'google', '13,20']
# sem google 13.20
# ['seo', 'yandex', '28,80']
# seo yandex 28.80
# ['sem', 'yandex', '22,00']
# sem yandex 22.00
# ['email', 'promo', '15,60']
# email promo 15.60
# ['sem', 'yandex', '13,60']
# sem yandex 13.60
# ['sem', 'google', '8,60']
# sem google 8.60
# ['sem', 'google', '22,00']
# sem google 22.00
# ['email', 'promo', '20,00']
# email promo 20.00
# ['sem', 'yandex', '12,60']
# sem yandex 12.60
# ['sem', 'google', '18,00']
# sem google 18.00
# ['brand', 'direct', '11,00']
# brand direct 11.00
# ['email', 'promo', '12,20']
# email promo 12.20
# ['sem', 'yandex', '18,00']
# sem yandex 18.00
# ['email', 'promo', '12,40']
# email promo 12.40
# ['seo', 'google', '13,00']
# seo google 13.00
# ['brand', 'direct', '21,40']
# brand direct 21.40
# ['sem', 'yandex', '13,60']
# sem yandex 13.60
# ['cpa-partners', 'food-delivery', '17,40']
# cpa-partners food-delivery 17.40
# ['sem', 'google', '15,00']
# sem google 15.00
# ['seo', 'yandex', '14,40']
# seo yandex 14.40
# ['brand', 'direct', '16,00']
# brand direct 16.00
# ['seo', 'yandex', '12,00']
# seo yandex 12.00
# ['sem', 'yandex', '12,80']
# sem yandex 12.80
# ['email', 'promo', '21,40']
# email promo 21.40
# ['sem', 'yandex', '17,40']
# sem yandex 17.40
# ['sem', 'yandex', '21,60']
# sem yandex 21.60
# ['email', 'promo', '16,00']
# email promo 16.00
# ['sem', 'google', '16,40']
# sem google 16.40
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['email', 'promo', '22,00']
# email promo 22.00
# ['brand', 'yandex', '21,80']
# brand yandex 21.80
# ['email', 'promo', '14,60']
# email promo 14.60
# ['seo', 'yandex', '22,00']
# seo yandex 22.00
# ['email', 'promo', '25,00']
# email promo 25.00
# ['sem', 'google', '15,60']
# sem google 15.60
# ['email', 'promo', '17,80']
# email promo 17.80
# ['sem', 'yandex', '14,80']
# sem yandex 14.80
# ['sem', 'yandex', '18,20']
# sem yandex 18.20
# ['sem', 'google', '12,60']
# sem google 12.60
# ['email', 'promo', '11,80']
# email promo 11.80
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['seo', 'yandex', '30,40']
# seo yandex 30.40
# ['seo', 'google', '13,40']
# seo google 13.40
# ['email', 'newsletter', '18,40']
# email newsletter 18.40
# ['email', 'promo', '20,00']
# email promo 20.00
# ['smm', 'vk', '17,00']
# smm vk 17.00
# ['sem', 'google', '26,00']
# sem google 26.00
# ['sem', 'google', '21,00']
# sem google 21.00
# ['cpc-partners', 'foody', '19,40']
# cpc-partners foody 19.40
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['sem', 'yandex', '12,80']
# sem yandex 12.80
# ['sem', 'google', '14,00']
# sem google 14.00
# ['cpa-partners', 'burgerclub', '21,80']
# cpa-partners burgerclub 21.80
# ['cpc-partners', 'city-magazine', '11,80']
# cpc-partners city-magazine 11.80
# ['sem', 'google', '25,80']
# sem google 25.80
# ['sem', 'google', '18,00']
# sem google 18.00
# ['sem', 'google', '10,20']
# sem google 10.20
# ['email', 'promo', '12,00']
# email promo 12.00
# ['sem', 'google', '13,80']
# sem google 13.80
# ['sem', 'google', '16,60']
# sem google 16.60
# ['sem', 'google', '11,40']
# sem google 11.40
# ['brand', 'google', '13,40']
# brand google 13.40
# ['sem', 'yandex', '14,00']
# sem yandex 14.00
# ['sem', 'google', '16,60']
# sem google 16.60
# ['email', 'promo', '24,00']
# email promo 24.00
# ['email', 'promo', '10,20']
# email promo 10.20
# ['email', 'promo', '18,60']
# email promo 18.60
# ['sem', 'yandex', '21,60']
# sem yandex 21.60
# ['cpa-partners', 'burgerclub', '20,20']
# cpa-partners burgerclub 20.20
# ['sem', 'yandex', '18,00']
# sem yandex 18.00
# ['email', 'promo', '17,40']
# email promo 17.40
# ['email', 'promo', '22,00']
# email promo 22.00
# ['sem', 'yandex', '17,40']
# sem yandex 17.40
# ['sem', 'yandex', '19,00']
# sem yandex 19.00
# ['smm', 'facebook', '18,00']
# smm facebook 18.00
# ['brand', 'google', '16,00']
# brand google 16.00
# ['email', 'promo', '28,60']
# email promo 28.60
# ['sem', 'yandex', '18,40']
# sem yandex 18.40
# ['email', 'promo', '18,80']
# email promo 18.80
# ['seo', 'yandex', '17,80']
# seo yandex 17.80
# ['sem', 'yandex', '16,80']
# sem yandex 16.80
# ['sem', 'yandex', '19,40']
# sem yandex 19.40
# ['sem', 'google', '20,00']
# sem google 20.00
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['sem', 'google', '22,00']
# sem google 22.00
# ['cpa-partners', 'food-delivery', '12,80']
# cpa-partners food-delivery 12.80
# ['email', 'promo', '20,00']
# email promo 20.00
# ['sem', 'yandex', '17,40']
# sem yandex 17.40
# ['email', 'promo', '15,60']
# email promo 15.60
# ['sem', 'google', '22,00']
# sem google 22.00
# ['sem', 'google', '14,40']
# sem google 14.40
# ['sem', 'google', '12,20']
# sem google 12.20
# ['seo', 'yandex', '12,20']
# seo yandex 12.20
# ['email', 'promo', '20,00']
# email promo 20.00
# ['cpa-partners', 'food-delivery', '13,00']
# cpa-partners food-delivery 13.00
# ['sem', 'yandex', '22,40']
# sem yandex 22.40
# ['sem', 'yandex', '13,60']
# sem yandex 13.60
# ['sem', 'google', '30,40']
# sem google 30.40
# ['sem', 'yandex', '12,40']
# sem yandex 12.40
# ['sem', 'yandex', '16,00']
# sem yandex 16.00
# ['seo', 'yandex', '30,40']
# seo yandex 30.40
# ['cpc-partners', 'city-magazine', '23,20']
# cpc-partners city-magazine 23.20
# ['sem', 'google', '20,00']
# sem google 20.00
# ['email', 'promo', '12,60']
# email promo 12.60
# ['sem', 'google', '14,60']
# sem google 14.60
# ['cpc-partners', 'city-magazine', '11,80']
# cpc-partners city-magazine 11.80
# ['smm', 'facebook', '20,20']
# smm facebook 20.20
# ['sem', 'google', '10,00']
# sem google 10.00
# ['email', 'promo', '12,80']
# email promo 12.80
# ['sem', 'yandex', '20,60']
# sem yandex 20.60
# ['seo', 'yandex', '18,00']
# seo yandex 18.00
# ['cpa-partners', 'food-delivery', '13,80']
# cpa-partners food-delivery 13.80
# ['seo', 'yandex', '12,80']
# seo yandex 12.80
# ['sem', 'yandex', '17,20']
# sem yandex 17.20
# ['sem', 'google', '16,00']
# sem google 16.00
# ['email', 'promo', '14,20']
# email promo 14.20
# ['sem', 'yandex', '19,60']
# sem yandex 19.60
# ['seo', 'google', '22,40']
# seo google 22.40
# ['email', 'promo', '14,80']
# email promo 14.80
# ['sem', 'google', '13,00']
# sem google 13.00
# ['sem', 'google', '13,60']
# sem google 13.60
# ['email', 'promo', '12,60']
# email promo 12.60
# ['seo', 'yandex', '19,20']
# seo yandex 19.20
# ['email', 'promo', '20,20']
# email promo 20.20
# ['sem', 'google', '16,00']
# sem google 16.00
# ['sem', 'yandex', '11,60']
# sem yandex 11.60

# %%
type (amount_paid)
# Out:
# str

# %%
with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',','.'))
        print (line)
        print (medium, source, amount_paid)
# Out:
# ['seo', 'google', '20,20']
# seo google 20.2
# ['sem', 'yandex', '15,60']
# sem yandex 15.6
# ['email', 'promo', '13,20']
# email promo 13.2
# ['sem', 'yandex', '9,80']
# sem yandex 9.8
# ['sem', 'google', '14,80']
# sem google 14.8
# ['sem', 'google', '14,40']
# sem google 14.4
# ['sem', 'google', '14,00']
# sem google 14.0
# ['brand', 'yandex', '20,00']
# brand yandex 20.0
# ['sem', 'yandex', '16,20']
# sem yandex 16.2
# ['email', 'promo', '11,00']
# email promo 11.0
# ['cpa-partners', 'burgerclub', '10,80']
# cpa-partners burgerclub 10.8
# ['seo', 'google', '22,60']
# seo google 22.6
# ['seo', 'google', '22,40']
# seo google 22.4
# ['sem', 'yandex', '24,40']
# sem yandex 24.4
# ['seo', 'google', '16,60']
# seo google 16.6
# ['sem', 'yandex', '8,60']
# sem yandex 8.6
# ['seo', 'yandex', '12,40']
# seo yandex 12.4
# ['cpa-partners', 'food-delivery', '16,20']
# cpa-partners food-delivery 16.2
# ['email', 'promo', '24,00']
# email promo 24.0
# ['sem', 'yandex', '18,80']
# sem yandex 18.8
# ['email', 'promo', '11,80']
# email promo 11.8
# ['sem', 'google', '9,40']
# sem google 9.4
# ['sem', 'google', '11,20']
# sem google 11.2
# ['email', 'promo', '19,00']
# email promo 19.0
# ['sem', 'google', '23,40']
# sem google 23.4
# ['cpc-partners', 'city-magazine', '17,00']
# cpc-partners city-magazine 17.0
# ['seo', 'google', '20,80']
# seo google 20.8
# ['email', 'promo', '15,60']
# email promo 15.6
# ['cpc-partners', 'foody', '22,40']
# cpc-partners foody 22.4
# ['seo', 'yandex', '15,60']
# seo yandex 15.6
# ['cpa-partners', 'food-delivery', '21,00']
# cpa-partners food-delivery 21.0
# ['seo', 'google', '22,40']
# seo google 22.4
# ['sem', 'google', '20,40']
# sem google 20.4
# ['email', 'promo', '26,00']
# email promo 26.0
# ['seo', 'yandex', '18,40']
# seo yandex 18.4
# ['email', 'promo', '14,60']
# email promo 14.6
# ['seo', 'yandex', '29,80']
# seo yandex 29.8
# ['email', 'promo', '20,00']
# email promo 20.0
# ['sem', 'google', '19,00']
# sem google 19.0
# ['brand', 'google', '16,40']
# brand google 16.4
# ['sem', 'yandex', '16,20']
# sem yandex 16.2
# ['sem', 'yandex', '17,80']
# sem yandex 17.8
# ['email', 'promo', '18,80']
# email promo 18.8
# ['cpa-partners', 'burgerclub', '20,00']
# cpa-partners burgerclub 20.0
# ['seo', 'google', '21,00']
# seo google 21.0
# ['seo', 'yandex', '16,60']
# seo yandex 16.6
# ['email', 'promo', '20,00']
# email promo 20.0
# ['sem', 'yandex', '19,80']
# sem yandex 19.8
# ['email', 'promo', '16,80']
# email promo 16.8
# ['cpa-partners', 'food-delivery', '24,00']
# cpa-partners food-delivery 24.0
# ['sem', 'yandex', '12,00']
# sem yandex 12.0
# ['sem', 'yandex', '10,20']
# sem yandex 10.2
# ['email', 'promo', '24,00']
# email promo 24.0
# ['sem', 'yandex', '15,80']
# sem yandex 15.8
# ['sem', 'yandex', '22,00']
# sem yandex 22.0
# ['sem', 'google', '17,40']
# sem google 17.4
# ['sem', 'yandex', '14,80']
# sem yandex 14.8
# ['email', 'promo', '20,00']
# email promo 20.0
# ['brand', 'yandex', '11,60']
# brand yandex 11.6
# ['seo', 'yandex', '20,00']
# seo yandex 20.0
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['seo', 'yandex', '11,20']
# seo yandex 11.2
# ['seo', 'google', '12,20']
# seo google 12.2
# ['sem', 'yandex', '19,20']
# sem yandex 19.2
# ['sem', 'google', '17,80']
# sem google 17.8
# ['sem', 'google', '19,80']
# sem google 19.8
# ['email', 'promo', '8,60']
# email promo 8.6
# ['email', 'promo', '28,60']
# email promo 28.6
# ['email', 'newsletter', '18,80']
# email newsletter 18.8
# ['sem', 'google', '17,60']
# sem google 17.6
# ['email', 'promo', '16,00']
# email promo 16.0
# ['cpa-partners', 'food-delivery', '15,40']
# cpa-partners food-delivery 15.4
# ['sem', 'yandex', '21,60']
# sem yandex 21.6
# ['email', 'promo', '7,60']
# email promo 7.6
# ['brand', 'yandex', '21,60']
# brand yandex 21.6
# ['smm', 'facebook', '17,40']
# smm facebook 17.4
# ['sem', 'google', '22,00']
# sem google 22.0
# ['email', 'promo', '22,00']
# email promo 22.0
# ['email', 'promo', '16,00']
# email promo 16.0
# ['seo', 'yandex', '16,00']
# seo yandex 16.0
# ['sem', 'yandex', '20,00']
# sem yandex 20.0
# ['email', 'promo', '10,00']
# email promo 10.0
# ['sem', 'yandex', '21,20']
# sem yandex 21.2
# ['seo', 'yandex', '30,40']
# seo yandex 30.4
# ['cpa-partners', 'burgerclub', '18,80']
# cpa-partners burgerclub 18.8
# ['sem', 'yandex', '14,00']
# sem yandex 14.0
# ['email', 'promo', '22,00']
# email promo 22.0
# ['sem', 'google', '16,00']
# sem google 16.0
# ['sem', 'yandex', '12,60']
# sem yandex 12.6
# ['sem', 'google', '13,40']
# sem google 13.4
# ['seo', 'yandex', '13,60']
# seo yandex 13.6
# ['sem', 'yandex', '10,20']
# sem yandex 10.2
# ['brand', 'yandex', '17,40']
# brand yandex 17.4
# ['sem', 'google', '22,40']
# sem google 22.4
# ['sem', 'yandex', '11,40']
# sem yandex 11.4
# ['sem', 'google', '14,00']
# sem google 14.0
# ['seo', 'yandex', '22,40']
# seo yandex 22.4
# ['sem', 'yandex', '18,00']
# sem yandex 18.0
# ['brand', 'direct', '17,00']
# brand direct 17.0
# ['cpa-partners', 'food-delivery', '24,80']
# cpa-partners food-delivery 24.8
# ['brand', 'google', '16,60']
# brand google 16.6
# ['sem', 'google', '17,80']
# sem google 17.8
# ['sem', 'google', '9,00']
# sem google 9.0
# ['email', 'promo', '10,60']
# email promo 10.6
# ['brand', 'google', '23,40']
# brand google 23.4
# ['cpa-partners', 'burgerclub', '21,00']
# cpa-partners burgerclub 21.0
# ['email', 'promo', '16,60']
# email promo 16.6
# ['cpc-partners', 'foody', '24,20']
# cpc-partners foody 24.2
# ['seo', 'google', '20,40']
# seo google 20.4
# ['seo', 'yandex', '25,60']
# seo yandex 25.6
# ['brand', 'yandex', '19,80']
# brand yandex 19.8
# ['smm', 'facebook', '16,40']
# smm facebook 16.4
# ['email', 'promo', '16,20']
# email promo 16.2
# ['seo', 'yandex', '17,00']
# seo yandex 17.0
# ['email', 'promo', '16,80']
# email promo 16.8
# ['sem', 'yandex', '19,80']
# sem yandex 19.8
# ['seo', 'yandex', '15,60']
# seo yandex 15.6
# ['email', 'newsletter', '19,20']
# email newsletter 19.2
# ['sem', 'google', '23,20']
# sem google 23.2
# ['sem', 'yandex', '10,80']
# sem yandex 10.8
# ['sem', 'google', '24,40']
# sem google 24.4
# ['sem', 'yandex', '13,40']
# sem yandex 13.4
# ['seo', 'yandex', '12,00']
# seo yandex 12.0
# ['smm', 'facebook', '18,60']
# smm facebook 18.6
# ['sem', 'google', '16,60']
# sem google 16.6
# ['cpa-partners', 'burgerclub', '12,20']
# cpa-partners burgerclub 12.2
# ['cpa-partners', 'burgerclub', '22,40']
# cpa-partners burgerclub 22.4
# ['seo', 'google', '15,40']
# seo google 15.4
# ['cpc-partners', 'city-magazine', '17,20']
# cpc-partners city-magazine 17.2
# ['cpa-partners', 'burgerclub', '17,60']
# cpa-partners burgerclub 17.6
# ['email', 'promo', '16,40']
# email promo 16.4
# ['email', 'promo', '18,60']
# email promo 18.6
# ['email', 'promo', '19,80']
# email promo 19.8
# ['brand', 'google', '18,80']
# brand google 18.8
# ['seo', 'google', '17,60']
# seo google 17.6
# ['email', 'promo', '20,60']
# email promo 20.6
# ['cpa-partners', 'food-delivery', '15,00']
# cpa-partners food-delivery 15.0
# ['sem', 'yandex', '22,00']
# sem yandex 22.0
# ['email', 'promo', '17,40']
# email promo 17.4
# ['seo', 'yandex', '13,60']
# seo yandex 13.6
# ['seo', 'yandex', '17,60']
# seo yandex 17.6
# ['email', 'promo', '18,40']
# email promo 18.4
# ['email', 'promo', '20,40']
# email promo 20.4
# ['sem', 'yandex', '20,00']
# sem yandex 20.0
# ['brand', 'yandex', '17,80']
# brand yandex 17.8
# ['seo', 'google', '16,00']
# seo google 16.0
# ['email', 'promo', '14,60']
# email promo 14.6
# ['email', 'promo', '17,20']
# email promo 17.2
# ['sem', 'yandex', '13,60']
# sem yandex 13.6
# ['email', 'promo', '23,60']
# email promo 23.6
# ['sem', 'google', '15,60']
# sem google 15.6
# ['sem', 'yandex', '21,40']
# sem yandex 21.4
# ['sem', 'google', '13,00']
# sem google 13.0
# ['seo', 'yandex', '18,60']
# seo yandex 18.6
# ['cpa-partners', 'burgerclub', '20,60']
# cpa-partners burgerclub 20.6
# ['seo', 'yandex', '11,40']
# seo yandex 11.4
# ['email', 'promo', '18,00']
# email promo 18.0
# ['smm', 'vk', '12,00']
# smm vk 12.0
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['sem', 'google', '12,20']
# sem google 12.2
# ['brand', 'direct', '23,00']
# brand direct 23.0
# ['sem', 'yandex', '24,00']
# sem yandex 24.0
# ['email', 'promo', '11,80']
# email promo 11.8
# ['email', 'newsletter', '17,20']
# email newsletter 17.2
# ['email', 'newsletter', '24,60']
# email newsletter 24.6
# ['sem', 'yandex', '30,40']
# sem yandex 30.4
# ['sem', 'yandex', '18,00']
# sem yandex 18.0
# ['email', 'promo', '15,00']
# email promo 15.0
# ['sem', 'google', '13,20']
# sem google 13.2
# ['seo', 'yandex', '28,80']
# seo yandex 28.8
# ['sem', 'yandex', '22,00']
# sem yandex 22.0
# ['email', 'promo', '15,60']
# email promo 15.6
# ['sem', 'yandex', '13,60']
# sem yandex 13.6
# ['sem', 'google', '8,60']
# sem google 8.6
# ['sem', 'google', '22,00']
# sem google 22.0
# ['email', 'promo', '20,00']
# email promo 20.0
# ['sem', 'yandex', '12,60']
# sem yandex 12.6
# ['sem', 'google', '18,00']
# sem google 18.0
# ['brand', 'direct', '11,00']
# brand direct 11.0
# ['email', 'promo', '12,20']
# email promo 12.2
# ['sem', 'yandex', '18,00']
# sem yandex 18.0
# ['email', 'promo', '12,40']
# email promo 12.4
# ['seo', 'google', '13,00']
# seo google 13.0
# ['brand', 'direct', '21,40']
# brand direct 21.4
# ['sem', 'yandex', '13,60']
# sem yandex 13.6
# ['cpa-partners', 'food-delivery', '17,40']
# cpa-partners food-delivery 17.4
# ['sem', 'google', '15,00']
# sem google 15.0
# ['seo', 'yandex', '14,40']
# seo yandex 14.4
# ['brand', 'direct', '16,00']
# brand direct 16.0
# ['seo', 'yandex', '12,00']
# seo yandex 12.0
# ['sem', 'yandex', '12,80']
# sem yandex 12.8
# ['email', 'promo', '21,40']
# email promo 21.4
# ['sem', 'yandex', '17,40']
# sem yandex 17.4
# ['sem', 'yandex', '21,60']
# sem yandex 21.6
# ['email', 'promo', '16,00']
# email promo 16.0
# ['sem', 'google', '16,40']
# sem google 16.4
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['email', 'promo', '22,00']
# email promo 22.0
# ['brand', 'yandex', '21,80']
# brand yandex 21.8
# ['email', 'promo', '14,60']
# email promo 14.6
# ['seo', 'yandex', '22,00']
# seo yandex 22.0
# ['email', 'promo', '25,00']
# email promo 25.0
# ['sem', 'google', '15,60']
# sem google 15.6
# ['email', 'promo', '17,80']
# email promo 17.8
# ['sem', 'yandex', '14,80']
# sem yandex 14.8
# ['sem', 'yandex', '18,20']
# sem yandex 18.2
# ['sem', 'google', '12,60']
# sem google 12.6
# ['email', 'promo', '11,80']
# email promo 11.8
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['seo', 'yandex', '30,40']
# seo yandex 30.4
# ['seo', 'google', '13,40']
# seo google 13.4
# ['email', 'newsletter', '18,40']
# email newsletter 18.4
# ['email', 'promo', '20,00']
# email promo 20.0
# ['smm', 'vk', '17,00']
# smm vk 17.0
# ['sem', 'google', '26,00']
# sem google 26.0
# ['sem', 'google', '21,00']
# sem google 21.0
# ['cpc-partners', 'foody', '19,40']
# cpc-partners foody 19.4
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['sem', 'yandex', '12,80']
# sem yandex 12.8
# ['sem', 'google', '14,00']
# sem google 14.0
# ['cpa-partners', 'burgerclub', '21,80']
# cpa-partners burgerclub 21.8
# ['cpc-partners', 'city-magazine', '11,80']
# cpc-partners city-magazine 11.8
# ['sem', 'google', '25,80']
# sem google 25.8
# ['sem', 'google', '18,00']
# sem google 18.0
# ['sem', 'google', '10,20']
# sem google 10.2
# ['email', 'promo', '12,00']
# email promo 12.0
# ['sem', 'google', '13,80']
# sem google 13.8
# ['sem', 'google', '16,60']
# sem google 16.6
# ['sem', 'google', '11,40']
# sem google 11.4
# ['brand', 'google', '13,40']
# brand google 13.4
# ['sem', 'yandex', '14,00']
# sem yandex 14.0
# ['sem', 'google', '16,60']
# sem google 16.6
# ['email', 'promo', '24,00']
# email promo 24.0
# ['email', 'promo', '10,20']
# email promo 10.2
# ['email', 'promo', '18,60']
# email promo 18.6
# ['sem', 'yandex', '21,60']
# sem yandex 21.6
# ['cpa-partners', 'burgerclub', '20,20']
# cpa-partners burgerclub 20.2
# ['sem', 'yandex', '18,00']
# sem yandex 18.0
# ['email', 'promo', '17,40']
# email promo 17.4
# ['email', 'promo', '22,00']
# email promo 22.0
# ['sem', 'yandex', '17,40']
# sem yandex 17.4
# ['sem', 'yandex', '19,00']
# sem yandex 19.0
# ['smm', 'facebook', '18,00']
# smm facebook 18.0
# ['brand', 'google', '16,00']
# brand google 16.0
# ['email', 'promo', '28,60']
# email promo 28.6
# ['sem', 'yandex', '18,40']
# sem yandex 18.4
# ['email', 'promo', '18,80']
# email promo 18.8
# ['seo', 'yandex', '17,80']
# seo yandex 17.8
# ['sem', 'yandex', '16,80']
# sem yandex 16.8
# ['sem', 'yandex', '19,40']
# sem yandex 19.4
# ['sem', 'google', '20,00']
# sem google 20.0
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['sem', 'google', '22,00']
# sem google 22.0
# ['cpa-partners', 'food-delivery', '12,80']
# cpa-partners food-delivery 12.8
# ['email', 'promo', '20,00']
# email promo 20.0
# ['sem', 'yandex', '17,40']
# sem yandex 17.4
# ['email', 'promo', '15,60']
# email promo 15.6
# ['sem', 'google', '22,00']
# sem google 22.0
# ['sem', 'google', '14,40']
# sem google 14.4
# ['sem', 'google', '12,20']
# sem google 12.2
# ['seo', 'yandex', '12,20']
# seo yandex 12.2
# ['email', 'promo', '20,00']
# email promo 20.0
# ['cpa-partners', 'food-delivery', '13,00']
# cpa-partners food-delivery 13.0
# ['sem', 'yandex', '22,40']
# sem yandex 22.4
# ['sem', 'yandex', '13,60']
# sem yandex 13.6
# ['sem', 'google', '30,40']
# sem google 30.4
# ['sem', 'yandex', '12,40']
# sem yandex 12.4
# ['sem', 'yandex', '16,00']
# sem yandex 16.0
# ['seo', 'yandex', '30,40']
# seo yandex 30.4
# ['cpc-partners', 'city-magazine', '23,20']
# cpc-partners city-magazine 23.2
# ['sem', 'google', '20,00']
# sem google 20.0
# ['email', 'promo', '12,60']
# email promo 12.6
# ['sem', 'google', '14,60']
# sem google 14.6
# ['cpc-partners', 'city-magazine', '11,80']
# cpc-partners city-magazine 11.8
# ['smm', 'facebook', '20,20']
# smm facebook 20.2
# ['sem', 'google', '10,00']
# sem google 10.0
# ['email', 'promo', '12,80']
# email promo 12.8
# ['sem', 'yandex', '20,60']
# sem yandex 20.6
# ['seo', 'yandex', '18,00']
# seo yandex 18.0
# ['cpa-partners', 'food-delivery', '13,80']
# cpa-partners food-delivery 13.8
# ['seo', 'yandex', '12,80']
# seo yandex 12.8
# ['sem', 'yandex', '17,20']
# sem yandex 17.2
# ['sem', 'google', '16,00']
# sem google 16.0
# ['email', 'promo', '14,20']
# email promo 14.2
# ['sem', 'yandex', '19,60']
# sem yandex 19.6
# ['seo', 'google', '22,40']
# seo google 22.4
# ['email', 'promo', '14,80']
# email promo 14.8
# ['sem', 'google', '13,00']
# sem google 13.0
# ['sem', 'google', '13,60']
# sem google 13.6
# ['email', 'promo', '12,60']
# email promo 12.6
# ['seo', 'yandex', '19,20']
# seo yandex 19.2
# ['email', 'promo', '20,20']
# email promo 20.2
# ['sem', 'google', '16,00']
# sem google 16.0
# ['sem', 'yandex', '11,60']
# sem yandex 11.6

# %%
type (amount_paid)
# Out:
# float

# %%
total_sum = 0

with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',','.'))
        total_sum += amount_paid
        print ('Текущая сумма расходов {:.2f}'.format(total_sum))
# Out:
# Текущая сумма расходов 20.20
# Текущая сумма расходов 35.80
# Текущая сумма расходов 49.00
# Текущая сумма расходов 58.80
# Текущая сумма расходов 73.60
# Текущая сумма расходов 88.00
# Текущая сумма расходов 102.00
# Текущая сумма расходов 122.00
# Текущая сумма расходов 138.20
# Текущая сумма расходов 149.20
# Текущая сумма расходов 160.00
# Текущая сумма расходов 182.60
# Текущая сумма расходов 205.00
# Текущая сумма расходов 229.40
# Текущая сумма расходов 246.00
# Текущая сумма расходов 254.60
# Текущая сумма расходов 267.00
# Текущая сумма расходов 283.20
# Текущая сумма расходов 307.20
# Текущая сумма расходов 326.00
# Текущая сумма расходов 337.80
# Текущая сумма расходов 347.20
# Текущая сумма расходов 358.40
# Текущая сумма расходов 377.40
# Текущая сумма расходов 400.80
# Текущая сумма расходов 417.80
# Текущая сумма расходов 438.60
# Текущая сумма расходов 454.20
# Текущая сумма расходов 476.60
# Текущая сумма расходов 492.20
# Текущая сумма расходов 513.20
# Текущая сумма расходов 535.60
# Текущая сумма расходов 556.00
# Текущая сумма расходов 582.00
# Текущая сумма расходов 600.40
# Текущая сумма расходов 615.00
# Текущая сумма расходов 644.80
# Текущая сумма расходов 664.80
# Текущая сумма расходов 683.80
# Текущая сумма расходов 700.20
# Текущая сумма расходов 716.40
# Текущая сумма расходов 734.20
# Текущая сумма расходов 753.00
# Текущая сумма расходов 773.00
# Текущая сумма расходов 794.00
# Текущая сумма расходов 810.60
# Текущая сумма расходов 830.60
# Текущая сумма расходов 850.40
# Текущая сумма расходов 867.20
# Текущая сумма расходов 891.20
# Текущая сумма расходов 903.20
# Текущая сумма расходов 913.40
# Текущая сумма расходов 937.40
# Текущая сумма расходов 953.20
# Текущая сумма расходов 975.20
# Текущая сумма расходов 992.60
# Текущая сумма расходов 1007.40
# Текущая сумма расходов 1027.40
# Текущая сумма расходов 1039.00
# Текущая сумма расходов 1059.00
# Текущая сумма расходов 1075.00
# Текущая сумма расходов 1086.20
# Текущая сумма расходов 1098.40
# Текущая сумма расходов 1117.60
# Текущая сумма расходов 1135.40
# Текущая сумма расходов 1155.20
# Текущая сумма расходов 1163.80
# Текущая сумма расходов 1192.40
# Текущая сумма расходов 1211.20
# Текущая сумма расходов 1228.80
# Текущая сумма расходов 1244.80
# Текущая сумма расходов 1260.20
# Текущая сумма расходов 1281.80
# Текущая сумма расходов 1289.40
# Текущая сумма расходов 1311.00
# Текущая сумма расходов 1328.40
# Текущая сумма расходов 1350.40
# Текущая сумма расходов 1372.40
# Текущая сумма расходов 1388.40
# Текущая сумма расходов 1404.40
# Текущая сумма расходов 1424.40
# Текущая сумма расходов 1434.40
# Текущая сумма расходов 1455.60
# Текущая сумма расходов 1486.00
# Текущая сумма расходов 1504.80
# Текущая сумма расходов 1518.80
# Текущая сумма расходов 1540.80
# Текущая сумма расходов 1556.80
# Текущая сумма расходов 1569.40
# Текущая сумма расходов 1582.80
# Текущая сумма расходов 1596.40
# Текущая сумма расходов 1606.60
# Текущая сумма расходов 1624.00
# Текущая сумма расходов 1646.40
# Текущая сумма расходов 1657.80
# Текущая сумма расходов 1671.80
# Текущая сумма расходов 1694.20
# Текущая сумма расходов 1712.20
# Текущая сумма расходов 1729.20
# Текущая сумма расходов 1754.00
# Текущая сумма расходов 1770.60
# Текущая сумма расходов 1788.40
# Текущая сумма расходов 1797.40
# Текущая сумма расходов 1808.00
# Текущая сумма расходов 1831.40
# Текущая сумма расходов 1852.40
# Текущая сумма расходов 1869.00
# Текущая сумма расходов 1893.20
# Текущая сумма расходов 1913.60
# Текущая сумма расходов 1939.20
# Текущая сумма расходов 1959.00
# Текущая сумма расходов 1975.40
# Текущая сумма расходов 1991.60
# Текущая сумма расходов 2008.60
# Текущая сумма расходов 2025.40
# Текущая сумма расходов 2045.20
# Текущая сумма расходов 2060.80
# Текущая сумма расходов 2080.00
# Текущая сумма расходов 2103.20
# Текущая сумма расходов 2114.00
# Текущая сумма расходов 2138.40
# Текущая сумма расходов 2151.80
# Текущая сумма расходов 2163.80
# Текущая сумма расходов 2182.40
# Текущая сумма расходов 2199.00
# Текущая сумма расходов 2211.20
# Текущая сумма расходов 2233.60
# Текущая сумма расходов 2249.00
# Текущая сумма расходов 2266.20
# Текущая сумма расходов 2283.80
# Текущая сумма расходов 2300.20
# Текущая сумма расходов 2318.80
# Текущая сумма расходов 2338.60
# Текущая сумма расходов 2357.40
# Текущая сумма расходов 2375.00
# Текущая сумма расходов 2395.60
# Текущая сумма расходов 2410.60
# Текущая сумма расходов 2432.60
# Текущая сумма расходов 2450.00
# Текущая сумма расходов 2463.60
# Текущая сумма расходов 2481.20
# Текущая сумма расходов 2499.60
# Текущая сумма расходов 2520.00
# Текущая сумма расходов 2540.00
# Текущая сумма расходов 2557.80
# Текущая сумма расходов 2573.80
# Текущая сумма расходов 2588.40
# Текущая сумма расходов 2605.60
# Текущая сумма расходов 2619.20
# Текущая сумма расходов 2642.80
# Текущая сумма расходов 2658.40
# Текущая сумма расходов 2679.80
# Текущая сумма расходов 2692.80
# Текущая сумма расходов 2711.40
# Текущая сумма расходов 2732.00
# Текущая сумма расходов 2743.40
# Текущая сумма расходов 2761.40
# Текущая сумма расходов 2773.40
# Текущая сумма расходов 2789.40
# Текущая сумма расходов 2801.60
# Текущая сумма расходов 2824.60
# Текущая сумма расходов 2848.60
# Текущая сумма расходов 2860.40
# Текущая сумма расходов 2877.60
# Текущая сумма расходов 2902.20
# Текущая сумма расходов 2932.60
# Текущая сумма расходов 2950.60
# Текущая сумма расходов 2965.60
# Текущая сумма расходов 2978.80
# Текущая сумма расходов 3007.60
# Текущая сумма расходов 3029.60
# Текущая сумма расходов 3045.20
# Текущая сумма расходов 3058.80
# Текущая сумма расходов 3067.40
# Текущая сумма расходов 3089.40
# Текущая сумма расходов 3109.40
# Текущая сумма расходов 3122.00
# Текущая сумма расходов 3140.00
# Текущая сумма расходов 3151.00
# Текущая сумма расходов 3163.20
# Текущая сумма расходов 3181.20
# Текущая сумма расходов 3193.60
# Текущая сумма расходов 3206.60
# Текущая сумма расходов 3228.00
# Текущая сумма расходов 3241.60
# Текущая сумма расходов 3259.00
# Текущая сумма расходов 3274.00
# Текущая сумма расходов 3288.40
# Текущая сумма расходов 3304.40
# Текущая сумма расходов 3316.40
# Текущая сумма расходов 3329.20
# Текущая сумма расходов 3350.60
# Текущая сумма расходов 3368.00
# Текущая сумма расходов 3389.60
# Текущая сумма расходов 3405.60
# Текущая сумма расходов 3422.00
# Текущая сумма расходов 3438.00
# Текущая сумма расходов 3460.00
# Текущая сумма расходов 3481.80
# Текущая сумма расходов 3496.40
# Текущая сумма расходов 3518.40
# Текущая сумма расходов 3543.40
# Текущая сумма расходов 3559.00
# Текущая сумма расходов 3576.80
# Текущая сумма расходов 3591.60
# Текущая сумма расходов 3609.80
# Текущая сумма расходов 3622.40
# Текущая сумма расходов 3634.20
# Текущая сумма расходов 3650.20
# Текущая сумма расходов 3680.60
# Текущая сумма расходов 3694.00
# Текущая сумма расходов 3712.40
# Текущая сумма расходов 3732.40
# Текущая сумма расходов 3749.40
# Текущая сумма расходов 3775.40
# Текущая сумма расходов 3796.40
# Текущая сумма расходов 3815.80
# Текущая сумма расходов 3831.80
# Текущая сумма расходов 3844.60
# Текущая сумма расходов 3858.60
# Текущая сумма расходов 3880.40
# Текущая сумма расходов 3892.20
# Текущая сумма расходов 3918.00
# Текущая сумма расходов 3936.00
# Текущая сумма расходов 3946.20
# Текущая сумма расходов 3958.20
# Текущая сумма расходов 3972.00
# Текущая сумма расходов 3988.60
# Текущая сумма расходов 4000.00
# Текущая сумма расходов 4013.40
# Текущая сумма расходов 4027.40
# Текущая сумма расходов 4044.00
# Текущая сумма расходов 4068.00
# Текущая сумма расходов 4078.20
# Текущая сумма расходов 4096.80
# Текущая сумма расходов 4118.40
# Текущая сумма расходов 4138.60
# Текущая сумма расходов 4156.60
# Текущая сумма расходов 4174.00
# Текущая сумма расходов 4196.00
# Текущая сумма расходов 4213.40
# Текущая сумма расходов 4232.40
# Текущая сумма расходов 4250.40
# Текущая сумма расходов 4266.40
# Текущая сумма расходов 4295.00
# Текущая сумма расходов 4313.40
# Текущая сумма расходов 4332.20
# Текущая сумма расходов 4350.00
# Текущая сумма расходов 4366.80
# Текущая сумма расходов 4386.20
# Текущая сумма расходов 4406.20
# Текущая сумма расходов 4422.20
# Текущая сумма расходов 4444.20
# Текущая сумма расходов 4457.00
# Текущая сумма расходов 4477.00
# Текущая сумма расходов 4494.40
# Текущая сумма расходов 4510.00
# Текущая сумма расходов 4532.00
# Текущая сумма расходов 4546.40
# Текущая сумма расходов 4558.60
# Текущая сумма расходов 4570.80
# Текущая сумма расходов 4590.80
# Текущая сумма расходов 4603.80
# Текущая сумма расходов 4626.20
# Текущая сумма расходов 4639.80
# Текущая сумма расходов 4670.20
# Текущая сумма расходов 4682.60
# Текущая сумма расходов 4698.60
# Текущая сумма расходов 4729.00
# Текущая сумма расходов 4752.20
# Текущая сумма расходов 4772.20
# Текущая сумма расходов 4784.80
# Текущая сумма расходов 4799.40
# Текущая сумма расходов 4811.20
# Текущая сумма расходов 4831.40
# Текущая сумма расходов 4841.40
# Текущая сумма расходов 4854.20
# Текущая сумма расходов 4874.80
# Текущая сумма расходов 4892.80
# Текущая сумма расходов 4906.60
# Текущая сумма расходов 4919.40
# Текущая сумма расходов 4936.60
# Текущая сумма расходов 4952.60
# Текущая сумма расходов 4966.80
# Текущая сумма расходов 4986.40
# Текущая сумма расходов 5008.80
# Текущая сумма расходов 5023.60
# Текущая сумма расходов 5036.60
# Текущая сумма расходов 5050.20
# Текущая сумма расходов 5062.80
# Текущая сумма расходов 5082.00
# Текущая сумма расходов 5102.20
# Текущая сумма расходов 5118.20
# Текущая сумма расходов 5129.80

# %%
total_sum = 0

with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',','.'))
        if source == 'google':
            total_sum += amount_paid
            print ('Текущая сумма расходов Google {:.2f}'.format(total_sum))
# Out:
# Текущая сумма расходов Google 20.20
# Текущая сумма расходов Google 35.00
# Текущая сумма расходов Google 49.40
# Текущая сумма расходов Google 63.40
# Текущая сумма расходов Google 86.00
# Текущая сумма расходов Google 108.40
# Текущая сумма расходов Google 125.00
# Текущая сумма расходов Google 134.40
# Текущая сумма расходов Google 145.60
# Текущая сумма расходов Google 169.00
# Текущая сумма расходов Google 189.80
# Текущая сумма расходов Google 212.20
# Текущая сумма расходов Google 232.60
# Текущая сумма расходов Google 251.60
# Текущая сумма расходов Google 268.00
# Текущая сумма расходов Google 289.00
# Текущая сумма расходов Google 306.40
# Текущая сумма расходов Google 318.60
# Текущая сумма расходов Google 336.40
# Текущая сумма расходов Google 356.20
# Текущая сумма расходов Google 373.80
# Текущая сумма расходов Google 395.80
# Текущая сумма расходов Google 411.80
# Текущая сумма расходов Google 425.20
# Текущая сумма расходов Google 447.60
# Текущая сумма расходов Google 461.60
# Текущая сумма расходов Google 478.20
# Текущая сумма расходов Google 496.00
# Текущая сумма расходов Google 505.00
# Текущая сумма расходов Google 528.40
# Текущая сумма расходов Google 548.80
# Текущая сумма расходов Google 572.00
# Текущая сумма расходов Google 596.40
# Текущая сумма расходов Google 613.00
# Текущая сумма расходов Google 628.40
# Текущая сумма расходов Google 647.20
# Текущая сумма расходов Google 664.80
# Текущая сумма расходов Google 680.80
# Текущая сумма расходов Google 696.40
# Текущая сумма расходов Google 709.40
# Текущая сумма расходов Google 721.60
# Текущая сумма расходов Google 734.80
# Текущая сумма расходов Google 743.40
# Текущая сумма расходов Google 765.40
# Текущая сумма расходов Google 783.40
# Текущая сумма расходов Google 796.40
# Текущая сумма расходов Google 811.40
# Текущая сумма расходов Google 827.80
# Текущая сумма расходов Google 843.40
# Текущая сумма расходов Google 856.00
# Текущая сумма расходов Google 869.40
# Текущая сумма расходов Google 895.40
# Текущая сумма расходов Google 916.40
# Текущая сумма расходов Google 930.40
# Текущая сумма расходов Google 956.20
# Текущая сумма расходов Google 974.20
# Текущая сумма расходов Google 984.40
# Текущая сумма расходов Google 998.20
# Текущая сумма расходов Google 1014.80
# Текущая сумма расходов Google 1026.20
# Текущая сумма расходов Google 1039.60
# Текущая сумма расходов Google 1056.20
# Текущая сумма расходов Google 1072.20
# Текущая сумма расходов Google 1092.20
# Текущая сумма расходов Google 1114.20
# Текущая сумма расходов Google 1136.20
# Текущая сумма расходов Google 1150.60
# Текущая сумма расходов Google 1162.80
# Текущая сумма расходов Google 1193.20
# Текущая сумма расходов Google 1213.20
# Текущая сумма расходов Google 1227.80
# Текущая сумма расходов Google 1237.80
# Текущая сумма расходов Google 1253.80
# Текущая сумма расходов Google 1276.20
# Текущая сумма расходов Google 1289.20
# Текущая сумма расходов Google 1302.80
# Текущая сумма расходов Google 1318.80

# %%
total_sum = 0

with open('module_02_data_3_columns.txt', 'r') as file:
    for line in file:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',','.'))
        if medium == 'seo' and source == 'yandex':
            total_sum += amount_paid
            print ('Текущая сумма расходов seo от yandex {:.2f}'.format(total_sum))
# Out:
# Текущая сумма расходов seo от yandex 12.40
# Текущая сумма расходов seo от yandex 28.00
# Текущая сумма расходов seo от yandex 46.40
# Текущая сумма расходов seo от yandex 76.20
# Текущая сумма расходов seo от yandex 92.80
# Текущая сумма расходов seo от yandex 112.80
# Текущая сумма расходов seo от yandex 124.00
# Текущая сумма расходов seo от yandex 140.00
# Текущая сумма расходов seo от yandex 170.40
# Текущая сумма расходов seo от yandex 184.00
# Текущая сумма расходов seo от yandex 206.40
# Текущая сумма расходов seo от yandex 232.00
# Текущая сумма расходов seo от yandex 249.00
# Текущая сумма расходов seo от yandex 264.60
# Текущая сумма расходов seo от yandex 276.60
# Текущая сумма расходов seo от yandex 290.20
# Текущая сумма расходов seo от yandex 307.80
# Текущая сумма расходов seo от yandex 326.40
# Текущая сумма расходов seo от yandex 337.80
# Текущая сумма расходов seo от yandex 366.60
# Текущая сумма расходов seo от yandex 381.00
# Текущая сумма расходов seo от yandex 393.00
# Текущая сумма расходов seo от yandex 415.00
# Текущая сумма расходов seo от yandex 445.40
# Текущая сумма расходов seo от yandex 463.20
# Текущая сумма расходов seo от yandex 475.40
# Текущая сумма расходов seo от yandex 505.80
# Текущая сумма расходов seo от yandex 523.80
# Текущая сумма расходов seo от yandex 536.60
# Текущая сумма расходов seo от yandex 555.80

# %% [markdown]
# ### Блок 4

# %%
import openpyxl

workbook = 'module_02_block_04_data.xlsx'
sheetName = 'data'

sheet = openpyxl.load_workbook(workbook)[sheetName]

for line in sheet['A1:I1']:
    print(line)
    print (line[0].value)
    print (line[4].value)
# Out:
# (<Cell 'data'.A1>, <Cell 'data'.B1>, <Cell 'data'.C1>, <Cell 'data'.D1>, <Cell 'data'.E1>, <Cell 'data'.F1>, <Cell 'data'.G1>, <Cell 'data'.H1>, <Cell 'data'.I1>)
# id
# medium

# %%
import openpyxl

workbook = 'module_02_block_04_data.xlsx'
sheetName = 'data'

sheet = openpyxl.load_workbook(workbook)[sheetName]

for line in sheet['E2:I5']:
    medium = line[0].value
    source = line[1].value
    amount_paid = line[4].value
    print(medium, source, amount_paid)
# Out:
# seo google 20.2
# sem yandex 15.6
# email promo 13.2
# sem yandex 9.8

# %%
type (amount_paid)
# Out:
# float

# %%
import openpyxl

total_amount_paid = 0

workbook = 'module_02_block_04_data.xlsx'
sheetName = 'data'

sheet = openpyxl.load_workbook(workbook)[sheetName]

for line in sheet['E2:I295']:
    medium = line[0].value
    source = line[1].value
    amount_paid = line[4].value
    total_amount_paid += amount_paid
    print(medium, source, amount_paid)
print(total_amount_paid)
# Out:
# seo google 20.2
# sem yandex 15.6
# email promo 13.2
# sem yandex 9.8
# sem google 14.8
# sem google 14.4
# sem google 14
# brand yandex 20
# sem yandex 16.2
# email promo 11
# cpa-partners burgerclub 10.8
# seo google 22.6
# seo google 22.4
# sem yandex 24.4
# seo google 16.6
# sem yandex 8.6
# seo yandex 12.4
# cpa-partners food-delivery 16.2
# email promo 24
# sem yandex 18.8
# email promo 11.8
# sem google 9.4
# sem google 11.2
# email promo 19
# sem google 23.4
# cpc-partners city-magazine 17
# seo google 20.8
# email promo 15.6
# cpc-partners foody 22.4
# seo yandex 15.6
# cpa-partners food-delivery 21
# seo google 22.4
# sem google 20.4
# email promo 26
# seo yandex 18.4
# email promo 14.6
# seo yandex 29.8
# email promo 20
# sem google 19
# brand google 16.4
# sem yandex 16.2
# sem yandex 17.8
# email promo 18.8
# cpa-partners burgerclub 20
# seo google 21
# seo yandex 16.6
# email promo 20
# sem yandex 19.8
# email promo 16.8
# cpa-partners food-delivery 24
# sem yandex 12
# sem yandex 10.2
# email promo 24
# sem yandex 15.8
# sem yandex 22
# sem google 17.4
# sem yandex 14.8
# email promo 20
# brand yandex 11.6
# seo yandex 20
# sem yandex 16
# seo yandex 11.2
# seo google 12.2
# sem yandex 19.2
# sem google 17.8
# sem google 19.8
# email promo 8.6
# email promo 28.6
# email newsletter 18.8
# sem google 17.6
# email promo 16
# cpa-partners food-delivery 15.4
# sem yandex 21.6
# email promo 7.6
# brand yandex 21.6
# smm facebook 17.4
# sem google 22
# email promo 22
# email promo 16
# seo yandex 16
# sem yandex 20
# email promo 10
# sem yandex 21.2
# seo yandex 30.4
# cpa-partners burgerclub 18.8
# sem yandex 14
# email promo 22
# sem google 16
# sem yandex 12.6
# sem google 13.4
# seo yandex 13.6
# sem yandex 10.2
# brand yandex 17.4
# sem google 22.4
# sem yandex 11.4
# sem google 14
# seo yandex 22.4
# sem yandex 18
# brand direct 17
# cpa-partners food-delivery 24.8
# brand google 16.6
# sem google 17.8
# sem google 9
# email promo 10.6
# brand google 23.4
# cpa-partners burgerclub 21
# email promo 16.6
# cpc-partners foody 24.2
# seo google 20.4
# seo yandex 25.6
# brand yandex 19.8
# smm facebook 16.4
# email promo 16.2
# seo yandex 17
# email promo 16.8
# sem yandex 19.8
# seo yandex 15.6
# email newsletter 19.2
# sem google 23.2
# sem yandex 10.8
# sem google 24.4
# sem yandex 13.4
# seo yandex 12
# smm facebook 18.6
# sem google 16.6
# cpa-partners burgerclub 12.2
# cpa-partners burgerclub 22.4
# seo google 15.4
# cpc-partners city-magazine 17.2
# cpa-partners burgerclub 17.6
# email promo 16.4
# email promo 18.6
# email promo 19.8
# brand google 18.8
# seo google 17.6
# email promo 20.6
# cpa-partners food-delivery 15
# sem yandex 22
# email promo 17.4
# seo yandex 13.6
# seo yandex 17.6
# email promo 18.4
# email promo 20.4
# sem yandex 20
# brand yandex 17.8
# seo google 16
# email promo 14.6
# email promo 17.2
# sem yandex 13.6
# email promo 23.6
# sem google 15.6
# sem yandex 21.4
# sem google 13
# seo yandex 18.6
# cpa-partners burgerclub 20.6
# seo yandex 11.4
# email promo 18
# smm vk 12
# sem yandex 16
# sem google 12.2
# brand direct 23
# sem yandex 24
# email promo 11.8
# email newsletter 17.2
# email newsletter 24.6
# sem yandex 30.4
# sem yandex 18
# email promo 15
# sem google 13.2
# seo yandex 28.8
# sem yandex 22
# email promo 15.6
# sem yandex 13.6
# sem google 8.6
# sem google 22
# email promo 20
# sem yandex 12.6
# sem google 18
# brand direct 11
# email promo 12.2
# sem yandex 18
# email promo 12.4
# seo google 13
# brand direct 21.4
# sem yandex 13.6
# cpa-partners food-delivery 17.4
# sem google 15
# seo yandex 14.4
# brand direct 16
# seo yandex 12
# sem yandex 12.8
# email promo 21.4
# sem yandex 17.4
# sem yandex 21.6
# email promo 16
# sem google 16.4
# sem yandex 16
# email promo 22
# brand yandex 21.8
# email promo 14.6
# seo yandex 22
# email promo 25
# sem google 15.6
# email promo 17.8
# sem yandex 14.8
# sem yandex 18.2
# sem google 12.6
# email promo 11.8
# sem yandex 16
# seo yandex 30.4
# seo google 13.4
# email newsletter 18.4
# email promo 20
# smm vk 17
# sem google 26
# sem google 21
# cpc-partners foody 19.4
# sem yandex 16
# sem yandex 12.8
# sem google 14
# cpa-partners burgerclub 21.8
# cpc-partners city-magazine 11.8
# sem google 25.8
# sem google 18
# sem google 10.2
# email promo 12
# sem google 13.8
# sem google 16.6
# sem google 11.4
# brand google 13.4
# sem yandex 14
# sem google 16.6
# email promo 24
# email promo 10.2
# email promo 18.6
# sem yandex 21.6
# cpa-partners burgerclub 20.2
# sem yandex 18
# email promo 17.4
# email promo 22
# sem yandex 17.4
# sem yandex 19
# smm facebook 18
# brand google 16
# email promo 28.6
# sem yandex 18.4
# email promo 18.8
# seo yandex 17.8
# sem yandex 16.8
# sem yandex 19.4
# sem google 20
# sem yandex 16
# sem google 22
# cpa-partners food-delivery 12.8
# email promo 20
# sem yandex 17.4
# email promo 15.6
# sem google 22
# sem google 14.4
# sem google 12.2
# seo yandex 12.2
# email promo 20
# cpa-partners food-delivery 13
# sem yandex 22.4
# sem yandex 13.6
# sem google 30.4
# sem yandex 12.4
# sem yandex 16
# seo yandex 30.4
# cpc-partners city-magazine 23.2
# sem google 20
# email promo 12.6
# sem google 14.6
# cpc-partners city-magazine 11.8
# smm facebook 20.2
# sem google 10
# email promo 12.8
# sem yandex 20.6
# seo yandex 18
# cpa-partners food-delivery 13.8
# seo yandex 12.8
# sem yandex 17.2
# sem google 16
# email promo 14.2
# sem yandex 19.6
# seo google 22.4
# email promo 14.8
# sem google 13
# sem google 13.6
# email promo 12.6
# seo yandex 19.2
# email promo 20.2
# sem google 16
# sem yandex 11.6
# 5129.8

# %% [markdown]
# ### Блок 5

# %%
total_costs = {'google': 1319, 'yandex':1818, 'promo':1181}
total_costs['google'] + total_costs['promo']
# Out:
# 2500

# %%
total_costs['brand']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-df6aaff9adb4> in <module>
# ----> 1 total_costs['brand']
#
# KeyError: 'brand'

# %%
source = 'google'

if source in total_costs:
    print('Расходы на источник {} составили {} рублей'.format(source, total_costs[source]))
else:
    print('Источник {} не найден в итоговой статистике'.format(source))
# Out:
# Расходы на источник google составили 1319 рублей

# %%
source = 'brand'

if source in total_costs:
    print('Расходы на источник {} составили {} рублей'.format(source, total_costs[source]))
else:
    print('Источник {} не найден в итоговой статистике'.format(source))
# Out:
# Источник brand не найден в итоговой статистике

# %%
for key in total_costs.keys():
    print(key)
# Out:
# google
# yandex
# promo

# %%
for value in total_costs.values():
    print(value)
# Out:
# 1319
# 1818
# 1181

# %%
for key, value in total_costs.items():
    print(key, value)
# Out:
# google 1319
# yandex 1818
# promo 1181

# %%
campaign_stats = {
    'google': {'cost': 1000, 'clicks': 500},
    'yandex': {'cost': 1500, 'clicks': 900}
}

for campaign, stats in campaign_stats.items():
    print('Кампания {}, цена клика {:.2f} USD'.format(campaign, stats['cost']/stats['clicks']))
# Out:
# Кампания google, цена клика 2.00 USD
# Кампания yandex, цена клика 1.67 USD

# %%
users_stats_dict = {}
i = 0

with open('module_02_block_05_data_no_header.txt','r') as file:
    for line in file:
        line = line.strip().split('\t')
        current_user_id = line[2]
        if current_user_id in users_stats_dict:
            users_stats_dict[current_user_id] +=1
        else:
            users_stats_dict[current_user_id] = 1
#        print('Текущий ID: {}'.format(current_user_id))
#        print(users_stats_dict)
#        print(' ')
#
#        i += 1
#        if i > 5:
#           break

users_stats_dict
# Out:
# {'1010': 1,
#  '1036': 1,
#  '1041': 2,
#  '1042': 12,
#  '1047': 2,
#  '1052': 2,
#  '1057': 2,
#  '1062': 1,
#  '1067': 1,
#  '1078': 1,
#  '1085': 1,
#  '1096': 1,
#  '1098': 1,
#  '1100': 12,
#  '1105': 1,
#  '1108': 9,
#  '1111': 1,
#  '1112': 2,
#  '1113': 2,
#  '1114': 2,
#  '1116': 1,
#  '1118': 2,
#  '1123': 2,
#  '1128': 1,
#  '1134': 2,
#  '1135': 9,
#  '1136': 2,
#  '1140': 2,
#  '1141': 1,
#  '1145': 2,
#  '1149': 7,
#  '1150': 1,
#  '1154': 2,
#  '1159': 2,
#  '1164': 1,
#  '1167': 1,
#  '1175': 1,
#  '1181': 1,
#  '1182': 2,
#  '1193': 2,
#  '1198': 2,
#  '1201': 1,
#  '1203': 2,
#  '1207': 14,
#  '1208': 2,
#  '1209': 1,
#  '1213': 2,
#  '1218': 2,
#  '1219': 1,
#  '1223': 2,
#  '1224': 1,
#  '1226': 2,
#  '1228': 2,
#  '1230': 1,
#  '1233': 2,
#  '1236': 1,
#  '1238': 2,
#  '1242': 1,
#  '1243': 2,
#  '1246': 24,
#  '1248': 2,
#  '1252': 2,
#  '1253': 2,
#  '1258': 2,
#  '1263': 2,
#  '1267': 17,
#  '1268': 2,
#  '1269': 1,
#  '1270': 1,
#  '1273': 2,
#  '1274': 1,
#  '1278': 2,
#  '1279': 1,
#  '1281': 1,
#  '1283': 2,
#  '1288': 2,
#  '1291': 1,
#  '1293': 2,
#  '1294': 1,
#  '1296': 1,
#  '1298': 3,
#  '1300': 2,
#  '1302': 1,
#  '1303': 2,
#  '1308': 2,
#  '1313': 2,
#  '1315': 1,
#  '1318': 14,
#  '1320': 1,
#  '1323': 2,
#  '1328': 2,
#  '1330': 1,
#  '1331': 1,
#  '1332': 1,
#  '1333': 1,
#  '1334': 1,
#  '1343': 1,
#  '1350': 1,
#  '1351': 1,
#  '1353': 1,
#  '1354': 1,
#  '1355': 1,
#  '1359': 1,
#  '1362': 1,
#  '1363': 1,
#  '1364': 1,
#  '1366': 1,
#  '1367': 1,
#  '1371': 1,
#  '1372': 1,
#  '1374': 1,
#  '1377': 1,
#  '1380': 1,
#  '1382': 1,
#  '1383': 1,
#  '1386': 1,
#  '1387': 1,
#  '1388': 1,
#  '1392': 1,
#  '1393': 1,
#  '1394': 1,
#  '1397': 1,
#  '1398': 1,
#  '1424': 15}
